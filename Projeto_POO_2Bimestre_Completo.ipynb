# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:** Guilherme Refundini
#
# **Turma:** 2°B Ti
#
# **Tema Escolhido:** Nota de Alunos

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class NotaAluno:
    def __init__(self, nome, matricula, notas):
        self.nome = nome
        self.matricula = matricula
        self.notas = notas

    def calcular_media(self):
        return sum(self.notas) / len(self.notas)
    
    def exibir_dados(self):
        media = self.calcular_media()
        print(f"Nome: {self.nome}")
        print(f"Matrícula: {self.matricula}")
        print(f"Notas: {', '.join(map(str, self.notas))}")
        print(f"Média: {media:.2f}")

aluno1 = NotaAluno("Maria Silva", "12345", [7.5, 8.0, 9.0])
aluno2 = NotaAluno("João Souza", "67890", [6.0, 7.0, 8.0])


aluno1.exibir_dados()
print()  
aluno2.exibir_dados()
# Out:
# Nome: Maria Silva
# Matrícula: 12345
# Notas: 7.5, 8.0, 9.0
# Média: 8.17
#
# Nome: João Souza
# Matrícula: 67890
# Notas: 6.0, 7.0, 8.0
# Média: 7.00

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class NotaAluno:
    def __init__(self, nome, matricula, notas):
        self.nome = nome
        self.matricula = matricula
        self.notas = notas

    def calcular_media(self):
        return sum(self.notas) / len(self.notas)
    
    def exibir_dados(self):
        media = self.calcular_media()
        print(f"Nome: {self.nome}")
        print(f"Matrícula: {self.matricula}")
        print(f"Notas: {', '.join(map(str, self.notas))}")
        print(f"Média: {media:.2f}")
    
    def adicionar_nota(self, nota):
        self.notas.append(nota)
        print(f"Nota {nota} adicionada com sucesso!")

    def remover_nota(self, nota):
        if nota in self.notas:
            self.notas.remove(nota)
            print(f"Nota {nota} removida com sucesso!")
        else:
            print(f"Nota {nota} não encontrada!")

class NotaAlunoAvancado(NotaAluno):
    def __init__(self, nome, matricula, notas, curso):
        super().__init__(nome, matricula, notas)
        self.curso = curso
    
    def exibir_curso(self):
        print(f"Curso: {self.curso}")

guilherme = NotaAluno("Guilherme Refundini", "12345", [7.5, 8.0, 9.0])
pedro = NotaAluno("Pedro Ramalho", "67890", [6.0, 7.0, 8.0])

gustavo = NotaAlunoAvancado("Gustavo Fadel", "11223", [9.5, 10.0, 8.5], "Engenharia")

print("Dados do aluno Guilherme:")
guilherme.exibir_dados()
print()

print("Dados do aluno Pedro:")
pedro.exibir_dados()
print()

print("Dados do aluno Gustavo:")
gustavo.exibir_dados()
gustavo.exibir_curso() 

guilherme.adicionar_nota(9.0)
guilherme.exibir_dados()

pedro.remover_nota(7.0)
pedro.exibir_dados()
# Out:
# Dados do aluno Guilherme:
# Nome: Guilherme Refundini
# Matrícula: 12345
# Notas: 7.5, 8.0, 9.0
# Média: 8.17
#
# Dados do aluno Pedro:
# Nome: Pedro Ramalho
# Matrícula: 67890
# Notas: 6.0, 7.0, 8.0
# Média: 7.00
#
# Dados do aluno Gustavo:
# Nome: Gustavo Fadel
# Matrícula: 11223
# Notas: 9.5, 10.0, 8.5
# Média: 9.33
# Curso: Engenharia
# Nota 9.0 adicionada com sucesso!
# Nome: Guilherme Refundini
# Matrícula: 12345
# Notas: 7.5, 8.0, 9.0, 9.0
# Média: 8.38
# Nota 7.0 removida com sucesso!
# Nome: Pedro Ramalho
# Matrícula: 67890
# Notas: 6.0, 8.0
# Média: 7.00

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class NotaAluno:
    def __init__(self, nome, matricula, notas):
        self.__notas = notas
        self.nome = nome
        self.matricula = matricula
    
    def calcular_media(self):
        return sum(self.__notas) / len(self.__notas)
    
    def exibir_dados(self):
        media = self.calcular_media()
        print(f"Nome: {self.nome}")
        print(f"Matrícula: {self.matricula}")
        print(f"Notas: {', '.join(map(str, self.__notas))}")
        print(f"Média: {media:.2f}")

    def adicionar_nota(self, nota):
        self.__notas.append(nota)
        print(f"Nota {nota} adicionada com sucesso!")
    
    def remover_nota(self, nota):
        if nota in self.__notas:
            self.__notas.remove(nota)
            print(f"Nota {nota} removida com sucesso!")
        else:
            print(f"Nota {nota} não encontrada!")
    
    def get_notas(self):
        return self.__notas
    
    def set_notas(self, novas_notas):
        if isinstance(novas_notas, list) and all(isinstance(nota, (int, float)) for nota in novas_notas):
            self.__notas = novas_notas
            print("Notas atualizadas com sucesso!")
        else:
            print("Erro: As notas precisam ser uma lista de números válidos.")

    def verificar_aprovacao(self):
        media = self.calcular_media()
        if media >= 7.0:
            return "Aprovado"
        else:
            return "Reprovado"

class NotaAlunoAvancado(NotaAluno):
    def __init__(self, nome, matricula, notas, curso):
        super().__init__(nome, matricula, notas)
        self.curso = curso
    
    def exibir_curso(self):
        print(f"Curso: {self.curso}")

guilherme = NotaAluno("Guilherme Refundini", "12345", [7.5, 8.0, 9.0])
pedro = NotaAluno("Pedro Ramalho", "67890", [6.0, 7.0, 8.0])
gustavo = NotaAlunoAvancado("Gustavo Fadel", "11223", [9.5, 10.0, 8.5], "Engenharia")

print("Dados do aluno Guilherme:")
guilherme.exibir_dados()
print(f"Aprovação: {guilherme.verificar_aprovacao()}")
print()

print("Dados do aluno Pedro:")
pedro.exibir_dados()
print(f"Aprovação: {pedro.verificar_aprovacao()}")
print()

print("Dados do aluno Gustavo:")
gustavo.exibir_dados()
gustavo.exibir_curso()  
print(f"Aprovação: {gustavo.verificar_aprovacao()}")

guilherme.adicionar_nota(9.0)
guilherme.exibir_dados()

pedro.remover_nota(7.0)
pedro.exibir_dados()

print("\nUsando os métodos get e set para as notas de Guilherme:")
print("Notas atuais:", guilherme.get_notas())
guilherme.set_notas([8.5, 9.0, 7.5])  
guilherme.exibir_dados()
# Out:
# Dados do aluno Guilherme:
# Nome: Guilherme Refundini
# Matrícula: 12345
# Notas: 7.5, 8.0, 9.0
# Média: 8.17
# Aprovação: Aprovado
#
# Dados do aluno Pedro:
# Nome: Pedro Ramalho
# Matrícula: 67890
# Notas: 6.0, 7.0, 8.0
# Média: 7.00
# Aprovação: Aprovado
#
# Dados do aluno Gustavo:
# Nome: Gustavo Fadel
# Matrícula: 11223
# Notas: 9.5, 10.0, 8.5
# Média: 9.33
# Curso: Engenharia
# Aprovação: Aprovado
# Nota 9.0 adicionada com sucesso!
# Nome: Guilherme Refundini
# Matrícula: 12345
# Notas: 7.5, 8.0, 9.0, 9.0
# Média: 8.38
# Nota 7.0 removida com sucesso!
# Nome: Pedro Ramalho
# Matrícula: 67890
# Notas: 6.0, 8.0
# Média: 7.00
#
# Usando os métodos get e set para as notas de Guilherme:
# Notas atuais: [7.5, 8.0, 9.0, 9.0]
# Notas atualizadas com sucesso!
# Nome: Guilherme Refundini
# Matrícula: 12345
# Notas: 8.5, 9.0, 7.5
# Média: 8.33

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3

class NotaAluno:
    def __init__(self, nome, matricula, notas):
        self.__notas = notas
        self.nome = nome
        self.matricula = matricula
    
    def calcular_media(self):
        return sum(self.__notas) / len(self.__notas)
    
    def exibir_dados(self):
        media = self.calcular_media()
        print(f"Nome: {self.nome}")
        print(f"Matrícula: {self.matricula}")
        print(f"Notas: {', '.join(map(str, self.__notas))}")
        print(f"Média: {media:.2f}")
    
    def adicionar_nota(self, nota):
        self.__notas.append(nota)
        print(f"Nota {nota} adicionada com sucesso!")
    
    def remover_nota(self, nota):
        if nota in self.__notas:
            self.__notas.remove(nota)
            print(f"Nota {nota} removida com sucesso!")
        else:
            print(f"Nota {nota} não encontrada!")
    
    def get_notas(self):
        return self.__notas
    
    def set_notas(self, novas_notas):
        if isinstance(novas_notas, list) and all(isinstance(nota, (int, float)) for nota in novas_notas):
            self.__notas = novas_notas
            print("Notas atualizadas com sucesso!")
        else:
            print("Erro: As notas precisam ser uma lista de números válidos.")

    def verificar_aprovacao(self):
        media = self.calcular_media()
        if media >= 7.0:
            return "Aprovado"
        else:
            return "Reprovado"
    
    def exibir_dados_completo(self):
        return f"Nome: {self.nome}, Matrícula: {self.matricula}, Média: {self.calcular_media():.2f}"

class NotaAlunoAvancado(NotaAluno):
    def __init__(self, nome, matricula, notas, curso):
        super().__init__(nome, matricula, notas)
        self.curso = curso
    
    def exibir_dados_completo(self):
        return f"Nome: {self.nome}, Matrícula: {self.matricula}, Curso: {self.curso}, Média: {self.calcular_media():.2f}"


def conectar_bd():
    return sqlite3.connect('alunos.db')


def criar_tabela():
    conn = conectar_bd()
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS alunos (
            matricula TEXT PRIMARY KEY,
            nome TEXT,
            notas TEXT,
            curso TEXT
        )
    """)
    conn.commit()
    conn.close()


def inserir_aluno(aluno):
    conn = conectar_bd()
    cursor = conn.cursor()
    
    notas_str = ','.join(map(str, aluno.get_notas())) 
    
    cursor.execute("""
        INSERT INTO alunos (matricula, nome, notas, curso) 
        VALUES (?, ?, ?, ?)
    """, (aluno.matricula, aluno.nome, notas_str, getattr(aluno, 'curso', None)))
    
    conn.commit()
    conn.close()
    print(f"Aluno {aluno.nome} inserido com sucesso no banco de dados!")


def consultar_aluno(matricula):
    conn = conectar_bd()
    cursor = conn.cursor()
    
    cursor.execute("SELECT * FROM alunos WHERE matricula=?", (matricula,))
    aluno = cursor.fetchone()
    
    if aluno:
        print(f"Aluno encontrado: Nome: {aluno[1]}, Matrícula: {aluno[0]}, Notas: {aluno[2]}, Curso: {aluno[3]}")
    else:
        print(f"Aluno com matrícula {matricula} não encontrado.")
    
    conn.close()


def excluir_aluno(matricula):
    conn = conectar_bd()
    cursor = conn.cursor()
    
    cursor.execute("DELETE FROM alunos WHERE matricula=?", (matricula,))
    conn.commit()
    
    if cursor.rowcount > 0:
        print(f"Aluno com matrícula {matricula} excluído com sucesso!")
    else:
        print(f"Aluno com matrícula {matricula} não encontrado.")
    
    conn.close()


guilherme = NotaAluno("Guilherme Refundini", "12345", [7.5, 8.0, 9.0])
pedro = NotaAluno("Pedro Ramalho", "67890", [6.0, 7.0, 8.0])

gustavo = NotaAlunoAvancado("Gustavo Fadel", "11223", [9.5, 10.0, 8.5], "Engenharia")

print(guilherme.exibir_dados_completo())
print(pedro.exibir_dados_completo())
print(gustavo.exibir_dados_completo())


criar_tabela()
inserir_aluno(guilherme)
inserir_aluno(pedro)
inserir_aluno(gustavo)
consultar_aluno("12345")
consultar_aluno("67890")
excluir_aluno("11223")
consultar_aluno("11223")
# Out:
# Nome: Guilherme Refundini, Matrícula: 12345, Média: 8.17
# Nome: Pedro Ramalho, Matrícula: 67890, Média: 7.00
# Nome: Gustavo Fadel, Matrícula: 11223, Curso: Engenharia, Média: 9.33
# Aluno Guilherme Refundini inserido com sucesso no banco de dados!
# Aluno Pedro Ramalho inserido com sucesso no banco de dados!
# Aluno Gustavo Fadel inserido com sucesso no banco de dados!
# Aluno encontrado: Nome: Guilherme Refundini, Matrícula: 12345, Notas: 7.5,8.0,9.0, Curso: None
# Aluno encontrado: Nome: Pedro Ramalho, Matrícula: 67890, Notas: 6.0,7.0,8.0, Curso: None
# Aluno com matrícula 11223 excluído com sucesso!
# Aluno com matrícula 11223 não encontrado.

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
def inserir_aluno(aluno):
    conn = conectar_bd()
    cursor = conn.cursor()

    cursor.execute("SELECT 1 FROM alunos WHERE matricula = ?", (aluno.matricula,))
    if cursor.fetchone():
        print(f"Erro: Aluno com matrícula {aluno.matricula} já está cadastrado.")
        conn.close()
        return

    notas_str = ','.join(map(str, aluno.get_notas()))
    cursor.execute("""
        INSERT INTO alunos (matricula, nome, notas, curso) 
        VALUES (?, ?, ?, ?)
    """, (aluno.matricula, aluno.nome, notas_str, getattr(aluno, 'curso', None)))

    conn.commit()
    conn.close()
    print(f"Aluno {aluno.nome} inserido com sucesso no banco de dados!")
