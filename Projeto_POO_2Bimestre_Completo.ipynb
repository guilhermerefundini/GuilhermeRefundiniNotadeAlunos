# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:** Guilherme Refundini
#
# **Turma:** 2°B Ti
#
# **Tema Escolhido:** Nota de Alunos

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Definição da classe principal
class Aluno:
    def __init__(self, nome, matricula, notas):
        self.nome = nome                  # Nome do aluno
        self.matricula = matricula        # Número de matrícula
        self.notas = notas                # Lista de notas (ex: [8.0, 7.5, 9.0])

    # Método para exibir os dados do aluno
    def exibir_dados(self):
        media = sum(self.notas) / len(self.notas)
        print(f"Nome: {self.nome}")
        print(f"Matrícula: {self.matricula}")
        print(f"Notas: {self.notas}")
        print(f"Média: {media:.2f}")
        print("-" * 30)

# Criação de objetos da classe Aluno
aluno1 = Aluno("Guilherme Refundini", "2025001", [8.5, 7.0, 9.2])
aluno2 = Aluno("Pedro Ramalho", "2025002", [6.0, 7.5, 8.0])
aluno3 = Aluno("Gustavo Fadel", "2025003", [9.0, 9.5, 10.0])

# Exibição dos dados dos alunos
aluno1.exibir_dados()
aluno2.exibir_dados()
aluno3.exibir_dados()
# Out:
# Nome: Maria Silva
# Matrícula: 12345
# Notas: 7.5, 3.9, 9.0
# Média: 6.80
#
# Nome: João Souza
# Matrícula: 67890
# Notas: 6.0, 7.0, 8.0
# Média: 7.00

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class Aluno:
    def __init__(self, nome, matricula, notas):
        self.nome = nome
        self.matricula = matricula
        self.notas = notas

    def calcular_media(self):
        return sum(self.notas) / len(self.notas)

    def exibir_dados(self):
        media = self.calcular_media()
        print(f"Nome: {self.nome}")
        print(f"Matrícula: {self.matricula}")
        print(f"Notas: {self.notas}")
        print(f"Média: {media:.2f}")
        print("-" * 30)

class AlunoGraduacao(Aluno):
    def __init__(self, nome, matricula, notas, curso):
        super().__init__(nome, matricula, notas)
        self.curso = curso

    def verificar_aprovacao(self):
        media = self.calcular_media()
        if media >= 7:
            return "Aprovado"
        else:
            return "Reprovado"

    def exibir_dados(self):
        super().exibir_dados()
        print(f"Curso: {self.curso}")
        print(f"Situação: {self.verificar_aprovacao()}")
        print("=" * 30)

aluno1 = AlunoGraduacao("Guilherme Refundini", "2025001", [8.5, 7.0, 9.2], "Engenharia")
aluno2 = AlunoGraduacao("Pedro Ramalho", "2025002", [6.0, 7.5, 8.0], "Administração")
aluno3 = AlunoGraduacao("Gustavo Fadel", "2025003", [9.0, 9.5, 10.0], "Ciência da Computação")

aluno1.exibir_dados()
aluno2.exibir_dados()
aluno3.exibir_dados()
# Out:
# Dados do aluno Guilherme:
# Nome: Guilherme Refundini
# Matrícula: 12345
# Notas: 7.5, 8.0, 9.0
# Média: 8.17
#
# Dados do aluno Pedro:
# Nome: Pedro Ramalho
# Matrícula: 67890
# Notas: 6.0, 7.0, 8.0
# Média: 7.00
#
# Dados do aluno Gustavo:
# Nome: Gustavo Fadel
# Matrícula: 11223
# Notas: 9.5, 10.0, 8.5
# Média: 9.33
# Curso: Engenharia
# Nota 9.0 adicionada com sucesso!
# Nome: Guilherme Refundini
# Matrícula: 12345
# Notas: 7.5, 8.0, 9.0, 9.0
# Média: 8.38
# Nota 7.0 removida com sucesso!
# Nome: Pedro Ramalho
# Matrícula: 67890
# Notas: 6.0, 8.0
# Média: 7.00

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class Aluno:
    def __init__(self, nome, matricula, notas):
        self.nome = nome
        self.__matricula = matricula
        self.notas = notas

    def get_matricula(self):
        return self.__matricula

    def set_matricula(self, nova_matricula):
        if isinstance(nova_matricula, str) and nova_matricula.isdigit():
            self.__matricula = nova_matricula
        else:
            print("Matrícula inválida. Deve conter apenas números.")

    def calcular_media(self):
        return sum(self.notas) / len(self.notas)

    def exibir_dados(self):
        media = self.calcular_media()
        print(f"Nome: {self.nome}")
        print(f"Matrícula: {self.get_matricula()}")
        print(f"Notas: {self.notas}")
        print(f"Média: {media:.2f}")
        print("-" * 30)

class AlunoGraduacao(Aluno):
    def __init__(self, nome, matricula, notas, curso):
        super().__init__(nome, matricula, notas)
        self.curso = curso

    def verificar_aprovacao(self):
        media = self.calcular_media()
        return "Aprovado" if media >= 7 else "Reprovado"

    def exibir_dados(self):
        super().exibir_dados()
        print(f"Curso: {self.curso}")
        print(f"Situação: {self.verificar_aprovacao()}")
        print("=" * 30)

aluno1 = AlunoGraduacao("Guilherme Refundini", "2025001", [8.5, 7.0, 9.2], "Engenharia")
aluno2 = AlunoGraduacao("Pedro Ramalho", "2025002", [6.0, 7.5, 8.0], "Administração")
aluno3 = AlunoGraduacao("Gustavo Fadel", "2025003", [9.0, 9.5, 10.0], "Ciência da Computação")

aluno1.exibir_dados()
aluno2.exibir_dados()
aluno3.exibir_dados()

# Exemplo de uso dos métodos get e set
aluno1.set_matricula("2025999")
print(f"Nova matrícula de {aluno1.nome}: {aluno1.get_matricula()}")
# Out:
# Dados do aluno Guilherme:
# Nome: Guilherme Refundini
# Matrícula: 12345
# Notas: 7.5, 8.0, 9.0
# Média: 8.17
# Aprovação: Aprovado
#
# Dados do aluno Pedro:
# Nome: Pedro Ramalho
# Matrícula: 67890
# Notas: 6.0, 7.0, 8.0
# Média: 7.00
# Aprovação: Aprovado
#
# Dados do aluno Gustavo:
# Nome: Gustavo Fadel
# Matrícula: 11223
# Notas: 9.5, 10.0, 8.5
# Média: 9.33
# Curso: Engenharia
# Aprovação: Aprovado
# Nota 9.0 adicionada com sucesso!
# Nome: Guilherme Refundini
# Matrícula: 12345
# Notas: 7.5, 8.0, 9.0, 9.0
# Média: 8.38
# Nota 7.0 removida com sucesso!
# Nome: Pedro Ramalho
# Matrícula: 67890
# Notas: 6.0, 8.0
# Média: 7.00
#
# Usando os métodos get e set para as notas de Guilherme:
# Notas atuais: [7.5, 8.0, 9.0, 9.0]
# Notas atualizadas com sucesso!
# Nome: Guilherme Refundini
# Matrícula: 12345
# Notas: 8.5, 9.0, 7.5
# Média: 8.33

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3

class Aluno:
    def __init__(self, nome, matricula, notas):
        self.nome = nome
        self.__matricula = matricula
        self.notas = notas

    def get_matricula(self):
        return self.__matricula

    def set_matricula(self, nova_matricula):
        if isinstance(nova_matricula, str) and nova_matricula.isdigit():
            self.__matricula = nova_matricula
        else:
            print("Matrícula inválida. Deve conter apenas números.")

    def calcular_media(self):
        return sum(self.notas) / len(self.notas)

    def exibir_dados(self):
        print(f"Nome: {self.nome}")
        print(f"Matrícula: {self.get_matricula()}")
        print(f"Notas: {self.notas}")
        print(f"Média: {self.calcular_media():.2f}")
        print("-" * 30)

class AlunoGraduacao(Aluno):
    def __init__(self, nome, matricula, notas, curso):
        super().__init__(nome, matricula, notas)
        self.curso = curso

    def verificar_aprovacao(self):
        return "Aprovado" if self.calcular_media() >= 7 else "Reprovado"

    def exibir_dados(self):
        super().exibir_dados()
        print(f"Curso: {self.curso}")
        print(f"Situação: {self.verificar_aprovacao()}")
        print("=" * 30)

# --- Banco de Dados ---

# Criação/Conexão com o banco
conn = sqlite3.connect("alunos.db")
cursor = conn.cursor()

# Criação da tabela (se não existir)
cursor.execute("""
CREATE TABLE IF NOT EXISTS alunos (
    nome TEXT,
    matricula TEXT PRIMARY KEY,
    notas TEXT,
    curso TEXT
)
""")
conn.commit()

# Funções para manipulação de dados
def inserir_aluno(aluno):
    notas_str = ",".join(map(str, aluno.notas))
    cursor.execute("INSERT INTO alunos (nome, matricula, notas, curso) VALUES (?, ?, ?, ?)",
                   (aluno.nome, aluno.get_matricula(), notas_str, aluno.curso))
    conn.commit()

def listar_alunos():
    cursor.execute("SELECT * FROM alunos")
    alunos = cursor.fetchall()
    for a in alunos:
        nome, matricula, notas_str, curso = a
        notas = list(map(float, notas_str.split(",")))
        aluno = AlunoGraduacao(nome, matricula, notas, curso)
        aluno.exibir_dados()

def excluir_aluno(matricula):
    cursor.execute("DELETE FROM alunos WHERE matricula = ?", (matricula,))
    conn.commit()

# --- Exemplo de uso ---

aluno1 = AlunoGraduacao("Guilherme Refundini", "2025001", [8.5, 7.0, 9.2], "Engenharia")
aluno2 = AlunoGraduacao("Pedro Ramalho", "2025002", [6.0, 7.5, 8.0], "Administração")
aluno3 = AlunoGraduacao("Gustavo Fadel", "2025003", [9.0, 9.5, 10.0], "Ciência da Computação")

inserir_aluno(aluno1)
inserir_aluno(aluno2)
inserir_aluno(aluno3)

print(">>> ALUNOS NO BANCO DE DADOS:")
listar_alunos()

excluir_aluno("2025002")

print("\n>>> APÓS EXCLUSÃO DO PEDRO RAMALHO:")
listar_alunos()

conn.close()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15268\2490135306.py in <module>
#      83 aluno3 = AlunoGraduacao("Gustavo Fadel", "2025003", [9.0, 9.5, 10.0], "Ciência da Computação")
#      84
# ---> 85 inserir_aluno(aluno1)
#      86 inserir_aluno(aluno2)
#      87 inserir_aluno(aluno3)
#
# ~\AppData\Local\Temp\ipykernel_15268\2490135306.py in inserir_aluno(aluno)
#      60 def inserir_aluno(aluno):
#      61     notas_str = ",".join(map(str, aluno.notas))
# ---> 62     cursor.execute("INSERT INTO alunos (nome, matricula, notas, curso) VALUES (?, ?, ?, ?)",
#      63                    (aluno.nome, aluno.get_matricula(), notas_str, aluno.curso))
#      64     conn.commit()
#
# IntegrityError: UNIQUE constraint failed: alunos.matricula

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import sqlite3

# -------------------------
# CLASSE PRINCIPAL Aluno
# -------------------------
class Aluno:
    def __init__(self, nome, matricula, notas):
        self.nome = nome
        self.__matricula = matricula
        self.notas = notas

    def get_matricula(self):
        return self.__matricula

    def set_matricula(self, nova_matricula):
        if isinstance(nova_matricula, str) and nova_matricula.isdigit():
            self.__matricula = nova_matricula
        else:
            print("Matrícula inválida!")

    def calcular_media(self):
        return sum(self.notas) / len(self.notas)

    def exibir_dados(self):
        print(f"Nome: {self.nome}")
        print(f"Matrícula: {self.get_matricula()}")
        print(f"Notas: {self.notas}")
        print(f"Média: {self.calcular_media():.2f}")

# -------------------------
# SUBCLASSE AlunoGraduacao
# -------------------------
class AlunoGraduacao(Aluno):
    def __init__(self, nome, matricula, notas, curso):
        super().__init__(nome, matricula, notas)
        self.curso = curso

    def verificar_aprovacao(self):
        return "Aprovado" if self.calcular_media() >= 7 else "Reprovado"

    def exibir_dados(self):
        super().exibir_dados()
        print(f"Curso: {self.curso}")
        print(f"Situação: {self.verificar_aprovacao()}")

# -------------------------
# BANCO NA MEMÓRIA
# -------------------------
conn = sqlite3.connect(":memory:")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE alunos (
    nome TEXT,
    matricula TEXT PRIMARY KEY,
    notas TEXT,
    curso TEXT
)
""")
conn.commit()

# -------------------------
# FUNÇÕES BANCO
# -------------------------
def inserir_aluno(aluno):
    notas_str = ",".join(map(str, aluno.notas))
    try:
        cursor.execute("INSERT INTO alunos (nome, matricula, notas, curso) VALUES (?, ?, ?, ?)",
                       (aluno.nome, aluno.get_matricula(), notas_str, aluno.curso))
        conn.commit()
    except sqlite3.IntegrityError:
        print("Erro: Matrícula já cadastrada!")

def listar_alunos():
    cursor.execute("SELECT * FROM alunos")
    registros = cursor.fetchall()
    if not registros:
        print("Nenhum aluno cadastrado.")
        return
    for nome, matricula, notas_str, curso in registros:
        notas = list(map(float, notas_str.split(",")))
        aluno = AlunoGraduacao(nome, matricula, notas, curso)
        aluno.exibir_dados()
        print("-" * 30)

def excluir_aluno(matricula):
    cursor.execute("DELETE FROM alunos WHERE matricula = ?", (matricula,))
    conn.commit()

# -------------------------
# INTERFACE SIMPLES
# -------------------------
def menu():
    while True:
        print("\n=== MENU ALUNOS ===")
        print("1 - Inserir aluno")
        print("2 - Listar alunos")
        print("3 - Excluir aluno por matrícula")
        print("0 - Sair")
        escolha = input("Opção: ")

        if escolha == "1":
            nome = input("Nome: ")
            matricula = input("Matrícula (somente números): ")
            notas_input = input("Notas separadas por vírgula (ex: 7.5,8.0,9.0): ")
            try:
                notas = [float(n) for n in notas_input.split(",")]
            except:
                print("Notas inválidas! Tente novamente.")
                continue
            curso = input("Curso: ")
            aluno = AlunoGraduacao(nome, matricula, notas, curso)
            inserir_aluno(aluno)
        elif escolha == "2":
            listar_alunos()
        elif escolha == "3":
            mat = input("Digite a matrícula para exclusão: ")
            excluir_aluno(mat)
            print("Aluno excluído, se matrícula existia.")
        elif escolha == "0":
            print("Saindo...")
            break
        else:
            print("Opção inválida! Tente novamente.")

# -------------------------
# EXECUÇÃO
# -------------------------
if __name__ == "__main__":
    menu()
    conn.close()
# Out:
# --- MENU ---
# 1 - Inserir novo aluno
# 2 - Listar alunos
# 3 - Excluir aluno por matrícula
# 0 - Sair
# Opção inválida.
#
# --- MENU ---
# 1 - Inserir novo aluno
# 2 - Listar alunos
# 3 - Excluir aluno por matrícula
# 0 - Sair
# Opção inválida.
#
# --- MENU ---
# 1 - Inserir novo aluno
# 2 - Listar alunos
# 3 - Excluir aluno por matrícula
# 0 - Sair
# Opção inválida.
#
# --- MENU ---
# 1 - Inserir novo aluno
# 2 - Listar alunos
# 3 - Excluir aluno por matrícula
# 0 - Sair
# Opção inválida.
#
# --- MENU ---
# 1 - Inserir novo aluno
# 2 - Listar alunos
# 3 - Excluir aluno por matrícula
# 0 - Sair
# Opção inválida.
#
# --- MENU ---
# 1 - Inserir novo aluno
# 2 - Listar alunos
# 3 - Excluir aluno por matrícula
# 0 - Sair
# Opção inválida.
#
# --- MENU ---
# 1 - Inserir novo aluno
# 2 - Listar alunos
# 3 - Excluir aluno por matrícula
# 0 - Sair
# Opção inválida.
#
# --- MENU ---
# 1 - Inserir novo aluno
# 2 - Listar alunos
# 3 - Excluir aluno por matrícula
# 0 - Sair
